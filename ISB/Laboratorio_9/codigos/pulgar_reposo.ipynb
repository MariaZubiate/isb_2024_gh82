# %%
pip install biosignalsnotebooks
# Out:
# Requirement already satisfied: biosignalsnotebooks in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (0.6.14)
# Requirement already satisfied: numpy==1.22.2 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (1.22.2)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (3.7.5)
# Requirement already satisfied: scipy==1.8.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (1.8.1)
# Requirement already satisfied: h5py in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (3.11.0)
# Requirement already satisfied: wget in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (3.2)
# Requirement already satisfied: datetime in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (5.5)
# Requirement already satisfied: bokeh==2.4.3 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (2.4.3)
# Requirement already satisfied: IPython in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (8.12.2)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (2.0.3)
# Requirement already satisfied: nbformat in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (5.10.4)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (2.32.2)
# Requirement already satisfied: libmagic in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (1.0)
# Requirement already satisfied: python-magic-bin in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from biosignalsnotebooks) (0.4.14)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (3.1.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (24.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (6.4)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from bokeh==2.4.3->biosignalsnotebooks) (4.11.0)
# Requirement already satisfied: zope.interface in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from datetime->biosignalsnotebooks) (6.4.post2)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from datetime->biosignalsnotebooks) (2024.1)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (5.14.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from IPython->biosignalsnotebooks) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (4.52.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from matplotlib->biosignalsnotebooks) (6.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from nbformat->biosignalsnotebooks) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from nbformat->biosignalsnotebooks) (4.22.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from nbformat->biosignalsnotebooks) (5.7.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from pandas->biosignalsnotebooks) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from requests->biosignalsnotebooks) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from requests->biosignalsnotebooks) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from requests->biosignalsnotebooks) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from requests->biosignalsnotebooks) (2024.2.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->biosignalsnotebooks) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jedi>=0.16->IPython->biosignalsnotebooks) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.3->biosignalsnotebooks) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->biosignalsnotebooks) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->biosignalsnotebooks) (306)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->biosignalsnotebooks) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from python-dateutil>=2.7->matplotlib->biosignalsnotebooks) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from stack-data->IPython->biosignalsnotebooks) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from stack-data->IPython->biosignalsnotebooks) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from stack-data->IPython->biosignalsnotebooks) (0.2.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from zope.interface->datetime->biosignalsnotebooks) (69.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pywavelets
# Out:
# Collecting pywavelets
#   Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\envs\isb_grupo9\lib\site-packages (from pywavelets) (1.22.2)
# Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.2 MB 653.6 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/4.2 MB 1.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.5/4.2 MB 3.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.7/4.2 MB 4.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.1/4.2 MB 4.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.2 MB 5.6 MB/s eta 0:00:01
#    ------------------ --------------------- 2.0/4.2 MB 6.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.5/4.2 MB 6.5 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.2 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.4/4.2 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.2 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 4.1/4.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: pywavelets
# Successfully installed pywavelets-1.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt

# Cargar data cruda
EMG_data = np.loadtxt('pulgar_reposo.txt')
columna_EMG = EMG_data[:, -1]
# Convertir los valores de la señal de 0-1023 a 0-3.3V
signal_EMG = ((columna_EMG - 507) / 1023) * 3.3 * 1000
# Frecuencia de muestreo del BiTalino: 1000 Hz
fs = 1000
N = len(signal_EMG)
# Crear el eje de tiempo
t = np.linspace(0, N/fs, N)

def Wavelet_filter_1(signal):  # Sym8
    wavelet = 'sym8'
    niveles = 9
    coeffs = pywt.wavedec(signal, wavelet, level=niveles)
    # Eliminar coeficientes específicos D1, D8, D9 y A9, según lo realizado en el Paper
    coeffs[0] = np.zeros_like(coeffs[0])  # A9
    coeffs[1] = np.zeros_like(coeffs[1])  # D9
    coeffs[2] = np.zeros_like(coeffs[2])  # D8
    coeffs[-1] = np.zeros_like(coeffs[-1])  # D1

    # Reconstrucción de la señal filtrada
    denoised_signal = pywt.waverec(coeffs, wavelet)
    return denoised_signal

def Wavelet_filter_2(signal):  # Db4
    wavelet = 'db4'
    niveles = 4
    coeffs = pywt.wavedec(signal, wavelet, level=niveles)
    # Hallar el Universal Threshold
    detail_coeffs = coeffs[-1]
    sigma = np.median(np.abs(detail_coeffs)) / 0.6745
    n = len(signal)
    threshold = sigma * np.sqrt(2 * np.log(n))
    # Aplicar el Threshold (soft) a los coeficientes
    new_coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]
    # Reconstrucción de la señal filtrada
    denoised_signal = pywt.waverec(new_coeffs, wavelet)
    return denoised_signal

def Wavelet_filter_3(signal):  # Rbio3.1
    wavelet = 'rbio3.1'
    niveles = 7
    coeffs = pywt.wavedec(signal, wavelet, level=niveles)
    # Eliminar coeficientes específicos D1, D6, D7 y A7, según lo realizado en el Paper
    coeffs[0] = np.zeros_like(coeffs[0])  # A7
    coeffs[1] = np.zeros_like(coeffs[1])  # D7
    coeffs[2] = np.zeros_like(coeffs[2])  # D6
    coeffs[3] = np.zeros_like(coeffs[3])  # D5
    # Reconstrucción de la señal filtrada
    denoised_signal = pywt.waverec(coeffs, wavelet)
    return denoised_signal

def calculate_snr(original_signal, filtered_signal):
    # Calcular el ruido
    noise = original_signal - filtered_signal
    # Potencia de la señal original
    signal_power = np.mean(original_signal ** 2)
    # Potencia del ruido
    noise_power = np.mean(noise ** 2)
    # Calcular SNR
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

def calculate_rms(original_signal, filtered_signal):
    signal = original_signal - filtered_signal
    rms = np.sqrt(np.mean(np.square(signal)))
    return rms

def MSE(original_signal, filtered_signal):
    mse = np.mean((original_signal - filtered_signal) ** 2)
    return mse

# FILTRO 1 = sym8
filtered_1 = Wavelet_filter_1(signal_EMG)
# FILTRO 2 = dB4
filtered_2 = Wavelet_filter_2(signal_EMG)
# FILTRO 3 = Rbio3.1
filtered_3 = Wavelet_filter_3(signal_EMG)

# Calcular SNR para cada filtro
snr_sym8 = calculate_snr(signal_EMG, filtered_1)
snr_db4 = calculate_snr(signal_EMG, filtered_2)
snr_rbio3_1 = calculate_snr(signal_EMG, filtered_3)

# Mostrar resultados de SNR
print(f"SNR Sym8: {snr_sym8:.2f} dB")
print(f"SNR Db4: {snr_db4:.2f} dB")
print(f"SNR Rbio3.1: {snr_rbio3_1:.2f} dB\n")

# Calcular el Error Cuadrático Medio (MSE)
mse_sym8 = MSE(signal_EMG, filtered_1)
mse_db4 = MSE(signal_EMG, filtered_2)
mse_rbio3_1 = MSE(signal_EMG, filtered_3)

# Mostrar resultados de MSE
print(f"MSE Sym8: {mse_sym8:.2f}")
print(f"MSE Db4: {mse_db4:.2f}")
print(f"MSE Rbio3.1: {mse_rbio3_1:.2f}\n")

rms_sym8 = calculate_rms(signal_EMG, filtered_1)
rms_db4 = calculate_rms(signal_EMG, filtered_2)
rms_rbio3_1 = calculate_rms(signal_EMG, filtered_3)

# Mostrar resultados de RMS
print(f"RMS Sym8: {rms_sym8:.4f}")
print(f"RMS DB4: {rms_db4:.4f}")
print(f"RMS Rbio3.1: {rms_rbio3_1:.4f}")
# Out:
# SNR Sym8: 6.42 dB
# SNR Db4: 0.64 dB
# SNR Rbio3.1: 0.93 dB
#
# MSE Sym8: 8.48
# MSE Db4: 32.09
# MSE Rbio3.1: 29.97
#
# RMS Sym8: 2.9124
# RMS DB4: 5.6651
# RMS Rbio3.1: 5.4743

# %%
# Plot de las señales originales y filtradas
plt.figure(figsize=(14, 10))

# Señal original
plt.subplot(4, 1, 1)
plt.plot(t, signal_EMG, label='Original EMG')
plt.title('Original EMG Signal')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude [mV]')

# Comparación de las señales originales y filtradas
plt.figure(figsize=(14, 10))

# Señal original y filtrada con Sym8
plt.subplot(3, 1, 1)
plt.plot(t, signal_EMG, label='Original EMG')
plt.plot(t[:len(filtered_1)], filtered_1, label='Filtered EMG (Sym8)', linestyle='--')
plt.title('Comparison of Original and Filtered EMG Signal (Sym8)')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude [mV]')
plt.legend()

# Señal original y filtrada con Db4
plt.subplot(3, 1, 2)
plt.plot(t, signal_EMG, label='Original EMG')
plt.plot(t[:len(filtered_2)], filtered_2, label='Filtered EMG (Db4)', linestyle='--')
plt.title('Comparison of Original and Filtered EMG Signal (Db4)')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude [mV]')
plt.legend()

# Señal original y filtrada con Rbio3.1
plt.subplot(3, 1, 3)
plt.plot(t, signal_EMG, label='Original EMG')
plt.plot(t[:len(filtered_3)], filtered_3, label='Filtered EMG (Rbio3.1)', linestyle='--')
plt.title('Comparison of Original and Filtered EMG Signal (Rbio3.1)')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude [mV]')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# PARAMETROS:

# %%
# Scientific packages
from numpy import linspace, array, mean, median, quantile, std, var
from scipy.stats import mode, skew, kurtosis

signal = filtered_1

# Let's calculate the standard deviation and the variance
mean_val = median(signal)
std_val = std(signal)
variance = var(signal)
skewness = skew(signal)
print('Mean: ', mean_val)
print('Standard deviation: ', std_val, '\nVariance: ', variance)
print('Skewness: ', skewness)
# Out:
# Mean:  -0.19199107348635788
# Standard deviation:  5.357137450241598
# Variance:  28.698921660781043
# Skewness:  0.3716207674774262
